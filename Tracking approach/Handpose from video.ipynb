# %% [markdown]
# # This notebook will be used to retrieve all handposes from all dataset videos.

# %%
import mediapipe as mp
import cv2
import numpy as np
import uuid
import os
from tqdm import tqdm
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
import scipy.interpolate
from scipy.interpolate import UnivariateSpline

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands
mp_face_mesh = mp.solutions.face_mesh

# %% [markdown]
# ## Open a video

# %%
cap = cv2.VideoCapture("dataset/videos/00414.mp4")
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        cv2.imshow('frame',frame)
    else:
        break
    if cv2.waitKey(20) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Detect handpose one a single video

# %%
hand_position = []
cap = cv2.VideoCapture("dataset/videos/00414.mp4")
with mp_hands.Hands(min_detection_confidence=0.8, min_tracking_confidence=0.5) as hands: 
    with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, refine_landmarks=True, min_detection_confidence=0.7) as face_mesh:
        while cap.isOpened():
            ret, frame = cap.read()

            if ret:

                # Flip on horizontal
                image = cv2.flip(frame, 1)

                # Set flag
                image.flags.writeable = False

                # Detections
                hand_results = hands.process(image)
                face_results = face_mesh.process(image)
                
                if hand_results.multi_handedness:
                    print(hand_results.multi_handedness)

                # Set flag to true
                image.flags.writeable = True

                # Rendering results
                
                #Detect hands position
                if hand_results.multi_hand_landmarks:
                    # At least one hand has been detected
                    temp_hand_position = []
                    for num, hand in enumerate(hand_results.multi_hand_landmarks):
                        mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS, 
                                                mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                                mp_drawing.DrawingSpec(color=(250, 44, 250), thickness=2, circle_radius=2),
                                                 )
                    hand_position.append(hand_results.multi_hand_landmarks)

                    #Detect face position
                    if face_results.multi_face_landmarks:
                        #Face has been detected
                        temp_face_position = []
                        for face_landmarks in face_results.multi_face_landmarks:
                            mp_drawing.draw_landmarks(
                              image,
                              landmark_list=face_landmarks,
                              connections=mp_face_mesh.FACEMESH_TESSELATION,
                              landmark_drawing_spec=None,
                              connection_drawing_spec=mp_drawing_styles
                              .get_default_face_mesh_tesselation_style())

                            mp_drawing.draw_landmarks(
                              image,
                              landmark_list=face_landmarks,
                              connections=mp_face_mesh.FACEMESH_CONTOURS,
                              landmark_drawing_spec=None,
                              connection_drawing_spec=mp_drawing_styles
                              .get_default_face_mesh_contours_style())
                            mp_drawing.draw_landmarks(
                              image,
                              landmark_list=face_landmarks,
                              connections=mp_face_mesh.FACEMESH_IRISES,
                              landmark_drawing_spec=None,
                              connection_drawing_spec=mp_drawing_styles
                              .get_default_face_mesh_iris_connections_style())
                        temp_face_position.append(face_results.multi_face_landmarks[0])

                # Showing our image    
                cv2.imshow('Hand and Face Tracking', image)
            else :
                break

            if cv2.waitKey(50) & 0xFF == ord('q'):
                break

cap.release()
cv2.destroyAllWindows()
# Out:
# [classification {
#   index: 1
#   score: 0.986327052116394
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9990025758743286
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9935113787651062
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9980832934379578
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9849422574043274
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9960534572601318
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9946630597114563
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9966831803321838
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9946225881576538
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9937425255775452
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9969989061355591
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9919272065162659
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9965115189552307
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9904816746711731
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9955020546913147
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9917380809783936
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9966610074043274
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9933611750602722
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9972465634346008
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9895439743995667
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9975342154502869
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9903624057769775
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9955745339393616
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9929988384246826
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9956721067428589
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9915392398834229
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.996737539768219
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9883370399475098
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.996738851070404
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9908013343811035
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9967331886291504
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9904899597167969
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9970401525497437
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9882595539093018
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9969319105148315
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9897393584251404
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9965546727180481
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9896882176399231
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9968754649162292
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9886561632156372
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9969109892845154
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9891088604927063
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9965194463729858
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9918729662895203
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9963319301605225
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9897690415382385
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9966556429862976
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9916501641273499
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9968494176864624
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9804722666740417
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9963013529777527
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9541857242584229
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9964095950126648
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9642865061759949
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.996375322341919
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9630053639411926
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9956246018409729
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9942078590393066
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9962448477745056
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9895160794258118
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9963334202766418
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9901643991470337
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9965642094612122
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9729686379432678
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9972860813140869
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.993506133556366
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9967078566551208
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9934716820716858
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9972813725471497
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9929742813110352
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9972854256629944
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9931721687316895
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9977709650993347
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9917253255844116
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9979739785194397
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.994086503982544
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9979973435401917
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9902597665786743
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9981997013092041
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.991278886795044
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9979777336120605
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9943563342094421
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.997834324836731
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.993316650390625
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9979324340820312
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9936551451683044
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9981093406677246
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9912410974502563
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9975470900535583
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9883313179016113
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9978732466697693
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9894374012947083
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9980043768882751
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9901779294013977
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9981877207756042
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9909461140632629
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9981243014335632
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9913308620452881
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9978947639465332
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.990768551826477
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9977855086326599
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.990618109703064
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9977120161056519
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9889410138130188
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9980056285858154
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9910030961036682
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9981616139411926
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9884597063064575
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9978547096252441
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9872046709060669
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9974499940872192
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9868614077568054
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9976826310157776
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9855489730834961
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9976605176925659
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9826772212982178
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.997261643409729
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.984246015548706
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9968309998512268
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.980954110622406
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9966484904289246
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9863525032997131
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9965662360191345
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9894667267799377
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9954875707626343
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9882714152336121
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9962299466133118
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9878630042076111
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9946075677871704
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9861333966255188
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9936732053756714
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9912427663803101
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9925695061683655
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9939728379249573
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9923751354217529
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9958916306495667
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9897180795669556
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9924119710922241
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9873338937759399
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9632328748703003
#   label: "Right"
# }
# ]

# %% [markdown]
# ### Get the first coordinate from the first recognized hand placement. Each tracked hand is composed of 21 reference points characterized by 3 coordinates: x, y (2D coordinates) and z (depth).

# %%
hand_position[2][0].landmark[0]
# Out:
# x: 0.36996397376060486
# y: 0.9045831561088562
# z: -1.5093831962076365e-08

# %%
hand_position[2][1].landmark[0]
# Out:
# x: 0.6783121824264526
# y: 0.875123143196106
# z: 5.7871204717230285e-08

# %%
def get_coordinate_from_landmark(landmark):
    ''' Extract 3D coordinates of a landmark'''
    return np.array([[landmark.x, landmark.y, landmark.z]])

def get_positions_from_track(tracks, handness=None):
    
    ''' Return a vector of length 42 linked to the 21 landmarks of each hand. 
        If a hand has not been recognized, landmarks 2D positions values are -1 by default
    '''
    # Notation : first 21 landmarks linked to left hand and the last 21 landmarks linked to right hand
    if handness:
        if len(handness) == 1:
            #A single hand has been tracked
            label = handness[0].classification[0].label
            simulated_hands = np.zeros(shape=(21, 3))
            all_positions = np.concatenate([get_coordinate_from_landmark(landmark) for landmark in tracks[0].landmark], axis = 0)
            if label == "Left":
                all_positions = np.concatenate((all_positions, simulated_hands), axis = 0)
            else:
                all_positions = np.concatenate((simulated_hands, all_positions), axis = 0)
        else:
            # Two hands has been detected
            label = handness[0].classification[0].label
            
            first_hand = np.concatenate([get_coordinate_from_landmark(landmark) for landmark in tracks[0].landmark], axis = 0)
            second_hand = np.concatenate([get_coordinate_from_landmark(landmark) for landmark in tracks[1].landmark], axis = 0)
            if label == "Left":
                all_positions = np.concatenate((first_hand, second_hand), axis = 0)
            else:
                all_positions = np.concatenate((second_hand, first_hand), axis = 0)

    else:
        all_positions = np.concatenate([get_coordinate_from_landmark(landmark) for landmark in tracks[0].landmark], axis = 0)
    return all_positions

def get_all_tracked_hand(finename_video):
    
    hand_position = []
    face_position = []
    cap = cv2.VideoCapture(finename_video)
    with mp_hands.Hands(min_detection_confidence=0.8, min_tracking_confidence=0.5) as hands: 
        with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, refine_landmarks=True, min_detection_confidence=0.7) as face_mesh:
            while cap.isOpened():
                ret, frame = cap.read()

                if ret:

                    # Flip on horizontal
                    image = cv2.flip(frame, 1)

                    # Set flag
                    image.flags.writeable = False

                    # Detections
                    hand_results = hands.process(image)
                    face_results = face_mesh.process(image)

                    if hand_results.multi_hand_landmarks:
                        # Hands has been recognized
                        handness = hand_results.multi_handedness
                                          
                        hand_position.append(get_positions_from_track(hand_results.multi_hand_landmarks, handness))
                        
                        if face_results.multi_face_landmarks:
                            #Face has been recognized
                            face_position.append(get_positions_from_track(face_results.multi_face_landmarks))
                        else:
                            face_position.append(-np.ones(shape = (478,3)))
                else :
                    break

    cap.release()
    
    hand_position = np.array(hand_position)
    face_position = np.array(face_position)
    if len(hand_position) != 0:
        all_position = np.concatenate((hand_position, face_position), axis = 1)
    else :
        all_position = []
    return all_position

# %%
track = get_all_tracked_hand("dataset/videos/00414.mp4")

# %%
track.shape
# Out:
# (71, 520, 3)

# %%
path_to_videos = os.getcwd()+'/dataset/videos'

# %% [markdown]
# ### Detecting all videos

# %%
hands_tracked = {}
for count, filename in tqdm(enumerate(os.listdir(path_to_videos))):
    track = get_all_tracked_hand(path_to_videos+'/'+filename)
    if len(track) > 0 :
        hands_tracked[filename] = track
    if count % 1000 == 0:
        pickle.dump(hands_tracked, open('all_record.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 11980it [36:23:27, 10.94s/it]

# %%
pickle.dump(hands_tracked, open('all_record.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)

# %%
len(hands_tracked)
# Out:
# 6178

# %% [markdown]
# Only 6178 videos contains at least one hand detected by mediapipe.

# %% [markdown]
# ## Analysing detections

# %%
len_sequence_video_detected = np.array([len(seq) for seq in hands_tracked.values()])

# %%
sns.distplot(len_sequence_video_detected)
# Out:
# C:\Users\thoma\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
len(len_sequence_video_detected[len_sequence_video_detected < 5])/len(len_sequence_video_detected)
# Out:
# 0.10440271932664293

# %% [markdown]
# 10% of the dataset contains sequence less than 5 images to depict a sign.

# %%
keys_dict = list(hands_tracked.keys())

# %%
cleaned_hands_tracked = { keys_dict[id_key] : hands_tracked[keys_dict[id_key]] for id_key in np.where(len_sequence_video_detected >= 5)[0]}

# %%
len(cleaned_hands_tracked)
# Out:
# 5533

# %%
len_sequence_video_detected = np.array([len(seq) for seq in cleaned_hands_tracked.values()])
sns.distplot(len_sequence_video_detected)
# Out:
# C:\Users\thoma\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#pickle.dump(cleaned_hands_tracked, open('record_cleaned.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
record = pickle.load(open("record_cleaned.pkl", "rb"))

# %%
min_ = [1, 1, 1]
max_ = [-1, -1, -1]
for elem in record.values():
    temp_min, temp_max = np.min(elem, axis = (0,1)), np.max(elem, axis = (0,1))
    for dim in range(3):
        if temp_min[dim] < min_[dim] :
            min_[dim] = temp_min[dim]
        if temp_max[dim] > max_[dim] :
            max_[dim] = temp_max[dim]

# %%
print(min_, max_)
# Out:
# [-0.06325573474168777, -0.12253961712121964, -0.2711982727050781] [1.0569168329238892, 1.1226613521575928, 0.1358286738395691]

# %%
min_ = np.array(min_)
max_ = np.array(max_)

# %%
for key in record.keys():
    dim1, dim2 = record[key].shape[:-1]
    record[key] = (record[key].reshape(dim1*dim2, 3) - min_)/(max_ - min_)
    record[key] = record[key].reshape(dim1, dim2, 3)

# %%
pickle.dump((min_, max_), open('Min_max.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Construct all tracking with the same number of sequence

# %% [markdown]
# Has it will be feed to a deep neural network, we need to have a fixed number of sequence for each record. To do that, a smooth interpolation will be made by using spline RBF interpolation.

# %%
number_of_sequences = 100

# %%
all_sequences = list(record.values())

# %%
all_sequences[0][0].shape
# Out:
# (520, 3)

# %%
all_sequences[0][0][21:42, 0]
# Out:
# array([0.63663753, 0.61766627, 0.59360556, 0.57123731, 0.55608442,
#        0.57360756, 0.53485428, 0.51063888, 0.4910689 , 0.57507291,
#        0.53363002, 0.50502999, 0.4818323 , 0.57978234, 0.54171776,
#        0.51667825, 0.49801867, 0.58618944, 0.55573786, 0.53646245,
#        0.52041435])

# %%
len(all_sequences[0])
# Out:
# 22

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

for nb_seq in range(len(all_sequences[0])):
    ax.scatter(all_sequences[0][nb_seq, 21:42, 0], all_sequences[0][nb_seq,21:42, 1], all_sequences[0][nb_seq, 21:42, 1], c = list(range(21)))
plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

ax.scatter(all_sequences[0][:, 21, 0], all_sequences[0][:,21, 1], all_sequences[0][:, 21, 1], c = list(range(len(all_sequences[0]))))
plt.show()

# %%
plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 0])
plt.show()
plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 1])
plt.show()
plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 2])
plt.show()

# %%
x = list(range(len(all_sequences[0])))
new_x = np.linspace(0, x[-1], number_of_sequences)

spl1 = UnivariateSpline(x, all_sequences[0][:, 21, 0], s=5e-6)
spl2 = UnivariateSpline(x, all_sequences[0][:, 21, 1], s=5e-6)
spl3 = UnivariateSpline(x, all_sequences[0][:, 21, 2], s=5e-6)

new_seq1 = spl1(new_x)
new_seq2 = spl2(new_x)
new_seq3 = spl3(new_x)

# %%
plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 0], c = 'red')
plt.scatter(new_x,new_seq1)
plt.show()

plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 1], c = 'red')
plt.scatter(new_x,new_seq2)
plt.show()

plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 2], c = 'red')
plt.scatter(new_x,new_seq3)
plt.show()

# %%
def spline_interpolation_landmark(landmark, number_of_sequences):
    '''
        Spline interpolation for a single landmark with shape(nb_seq, 3)
    '''
    
    x = list(range(len(landmark)))
    new_x = np.linspace(0, x[-1], number_of_sequences)

    spl1 = UnivariateSpline(x, landmark[:, 0], s=5e-6)
    spl2 = UnivariateSpline(x, landmark[:, 1], s=5e-6)
    spl3 = UnivariateSpline(x, landmark[:, 2], s=5e-6)

    new_seq1 = spl1(new_x)
    new_seq2 = spl2(new_x)
    new_seq3 = spl3(new_x)
    
    interpolated_landmark = np.vstack((new_seq1, new_seq2, new_seq3)).T
    return interpolated_landmark

# %%
test = spline_interpolation_landmark(all_sequences[0][:,21,:], number_of_sequences)

# %%
plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 0], c = 'red')
plt.scatter(new_x, test[:,0])
plt.show()

plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 1], c = 'red')
plt.scatter(new_x, test[:,1])
plt.show()

plt.scatter(list(range(len(all_sequences[0]))), all_sequences[0][:, 21, 2], c = 'red')
plt.scatter(new_x, test[:,2])
plt.show()

# %%
def spline_interpolation_landmarks(landmarks, number_of_sequences):
    '''
        Spline interpolation for all landmarks with shape(nb_seq, nb_landmarks, 3)
    '''
    
    interpolation = []
    for landmark in landmarks:
        interpolation.append(spline_interpolation_landmark(landmark, number_of_sequences))
    interpolation = np.array(interpolation)
    
    return interpolation

# %%
test = spline_interpolation_landmarks(all_sequences[0].reshape(520, 22, 3), number_of_sequences)

# %%
test.shape
# Out:
# (520, 100, 3)

# %%
def all_videos_interpolation(all_record, number_of_sequences):
    
    """
        Spline interpolation for all videos saved into a dictionary format
    """
    interpolation = {}
    for key_record, values_records in tqdm(all_record.items()):
        nb_seq, nb_landmarks = values_records.shape[:-1]
        interpolation[key_record] = spline_interpolation_landmarks(values_records.reshape(nb_landmarks, nb_seq, 3), number_of_sequences)

    return interpolation

# %%
final_cleaned_record = all_videos_interpolation(record, number_of_sequences)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5533/5533 [30:46<00:00,  3.00it/s]

# %%
pickle.dump(final_cleaned_record, open('final_record_cleaned.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
#record = pickle.load(open("final_record_cleaned.pkl", "rb"))
